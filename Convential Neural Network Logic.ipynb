# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import cv2

# %% [markdown]
# <b style='color:purple'>Sometimes our pixel inputs might has different positions and we cannot catch the visuals. To avoid this transform sliding problem, we can use filtering method to increase our prediction ratio. And the logic of behind :

# %%
plt.figure(figsize=(8,6));
plt.matshow(cv2.imread("Images/6.png"),fignum=1);

# %% [markdown]
# <b style='color:purple'>Here we apply our 3x3 filter to determine our target box. And to see similar solutions better we can use relu activation function. ( As we do in keras model )

# %%
plt.figure(figsize=(8,6));
plt.matshow(cv2.imread("Images/1.png"),fignum=1);

# %% [markdown]
# And other example to find koala

# %%
plt.figure(figsize=(8,6));
plt.matshow(cv2.imread("Images/4.png"),fignum=1);

# %% [markdown]
# <p style='color:purple'>Now we can collect our data from other body parts like this: collecting operation called <b>Pooling

# %%
plt.figure(figsize=(8,6));
plt.matshow(cv2.imread("Images/3.png"),fignum=1);

# %% [markdown]
# <b style='color:purple'>And then we can apply flatten operation to our data to give our ANN as input

# %%
plt.figure(figsize=(8,6));
plt.matshow(cv2.imread("Images/2.png"),fignum=1);
